# %%
import pandas as pd
import json
import ast

# %% [markdown]
# ### Cargo las base de datos

# %%
data = []
with open(r'Dataset\\output_steam_games.json', 'r', encoding='utf-8') as file:
    for line in file:
        try:
            data.append(json.loads(line))
        except json.JSONDecodeError:
            continue  # Skip the line if it can't be parsed

# %%
df = pd.DataFrame(data)
df
# Out:
#               publisher                                 genres  \
# 0                   NaN                                    NaN
# 1                   NaN                                    NaN
# 2                   NaN                                    NaN
# 3                   NaN                                    NaN
# 4                   NaN                                    NaN
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444              NaN                                    NaN
#
#                         app_name                     title  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# ...

# %%
df = df.dropna()
df
# Out:
#                   publisher  \
# 88310             Kotoshiro
# 88311      Making Fun, Inc.
# 88312          Poolians.com
# 88313                  彼岸领域
# 88315   Trickjump Games Ltd
# ...                     ...
# 120439      Bidoniera Games
# 120440      Ghost_RUS Games
# 120441               Sacada
# 120442         Laush Studio
# 120443             SIXNAILS
#
#                                                    genres  \
# 88310       [Action, Casual, Indie, Simulation, Strategy]
# 88311                [Free to Play, Indie, RPG, Strategy]
# 88312   [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                         [Action, Adventure, Casual]
# 88315                     [Action, Adventure, Simulation]
# ...                                                   ...
# 120439                 [Action, Adventure, Casual, Indie]
# 120440              [Casual, Indie, Simulation, Strategy]
# 120441                          [Casual, Indie, Strategy]
# ...

# %%
df1 = df.copy()

# %%
# Creo el dataframe con las columnas que nesecito para poder crear las funciones.
df2 = df1[['developer','id', 'release_date', 'price']].copy()
df2
# Out:
#                        developer      id release_date         price
# 88310                  Kotoshiro  761140   2018-01-04          4.99
# 88311           Secret Level SRL  643980   2018-01-04  Free To Play
# 88312               Poolians.com  670290   2017-07-24  Free to Play
# 88313                       彼岸领域  767400   2017-12-07          0.99
# 88315        Trickjump Games Ltd  772540   2018-01-04          3.99
# ...                          ...     ...          ...           ...
# 120439           Bidoniera Games  745400   2018-01-04          1.99
# 120440        Nikita "Ghost_RUS"  773640   2018-01-04          1.99
# 120441                    Sacada  733530   2018-01-04          4.99
# 120442  Laush Dmitriy Sergeevich  610660   2018-01-04          1.99
# 120443             xropi,stev3ns  658870   2017-09-02          4.99
#
# [22530 rows x 4 columns]

# %% [markdown]
# ### Normalizo la columna price... Free to play y free to use lo volvemos a valor 0.

# %%
df2['price'] = df2['price'].replace('Free to Play', 0)

# %%
df2['price'] = df2['price'].replace('Free to Use', 0)

# %%
df2['price'] = df2['price'].replace('Free To Play', 0)

# %%
df2['price'] = df2['price'].replace('Free To Use', 0)

# %%
df2
# Out:
#                        developer      id release_date price
# 88310                  Kotoshiro  761140   2018-01-04  4.99
# 88311           Secret Level SRL  643980   2018-01-04     0
# 88312               Poolians.com  670290   2017-07-24     0
# 88313                       彼岸领域  767400   2017-12-07  0.99
# 88315        Trickjump Games Ltd  772540   2018-01-04  3.99
# ...                          ...     ...          ...   ...
# 120439           Bidoniera Games  745400   2018-01-04  1.99
# 120440        Nikita "Ghost_RUS"  773640   2018-01-04  1.99
# 120441                    Sacada  733530   2018-01-04  4.99
# 120442  Laush Dmitriy Sergeevich  610660   2018-01-04  1.99
# 120443             xropi,stev3ns  658870   2017-09-02  4.99
#
# [22530 rows x 4 columns]

# %%
#Cambio el nombre de la columna 'id' por el de 'item_id' para poder hacer el merge con los archivos procesados
# 'developer_db' y 'user_reviews'.  
df2 =df2.rename(columns={'id':'item_id'})
df2
# Out:
#                        developer item_id release_date price
# 88310                  Kotoshiro  761140   2018-01-04  4.99
# 88311           Secret Level SRL  643980   2018-01-04     0
# 88312               Poolians.com  670290   2017-07-24     0
# 88313                       彼岸领域  767400   2017-12-07  0.99
# 88315        Trickjump Games Ltd  772540   2018-01-04  3.99
# ...                          ...     ...          ...   ...
# 120439           Bidoniera Games  745400   2018-01-04  1.99
# 120440        Nikita "Ghost_RUS"  773640   2018-01-04  1.99
# 120441                    Sacada  733530   2018-01-04  4.99
# 120442  Laush Dmitriy Sergeevich  610660   2018-01-04  1.99
# 120443             xropi,stev3ns  658870   2017-09-02  4.99
#
# [22530 rows x 4 columns]

# %%
# Elimino las filas en release date que tengan valores SOON.
df2 = df2[df2['release_date'] != 'SOON']

# %%
df2 = df2[df2['release_date'] != 'SOON™']

# %%
df2['release_date'] = pd.to_datetime(df2['release_date'], format='mixed')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22528 entries, 88310 to 120443
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   developer     22528 non-null  object
#  1   item_id       22528 non-null  object
#  2   release_date  22528 non-null  datetime64[ns]
#  3   price         22528 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 880.0+ KB

# %%
df2.to_csv(r'Dataset\Procesado\developer_db.csv', index=False)

# %%
#Cargo el archivo developer_db para hacer un merge con la base de datos
dfs = pd.read_csv(r'Dataset\Procesado\sentiment.csv')

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59305 entries, 0 to 59304
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   item_id   59305 non-null  float64
#  1   malo      59305 non-null  int64
#  2   neutral   59305 non-null  int64
#  3   positivo  59305 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 1.8 MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22528 entries, 88310 to 120443
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   developer     22528 non-null  object
#  1   item_id       22528 non-null  object
#  2   release_date  22528 non-null  datetime64[ns]
#  3   price         22528 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 880.0+ KB

# %%
#convierto la columna 'item_id' al tipo int
df2['item_id'] = df2['item_id'].astype(int)
dfs['item_id'] = dfs['item_id'].astype(int)

# %%
# Hago un merge de los dos archivos utilizando item_id como columna comun.
dev_df = pd.merge(dfs, df2, on='item_id', how='inner')

# %%
dev_df
# Out:
#        item_id  malo  neutral  positivo             developer release_date  \
# 0         1250     0        0         1  Tripwire Interactive   2009-05-14
# 1        22200     0        0         1              ACE Team   2009-04-21
# 2       227300     0        0         1          SCS Software   2013-01-16
# 3       239030     0        0         1                  3909   2013-08-08
# 4       248820     0        0         1      Hopoo Games, LLC   2013-11-08
# ...        ...   ...      ...       ...                   ...          ...
# 49052       70     0        0         1                 Valve   1998-11-08
# 49053   362890     0        0         1    Crowbar Collective   2015-05-05
# 49054   273110     0        0         1                 Nexon   2014-10-07
# 49055      730     0        0         1                 Valve   2012-08-21
# 49056      440     0        0         1                 Valve   2007-10-10
#
#        price
# 0      19.99
# 1       9.99
# 2      19.99
# ...

# %%
#Salvo el dataframe para utilizarlo en las consultas en la api.
dev_df.to_csv(r'Dataset\Procesado\dev_db.csv')
